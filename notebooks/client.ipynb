# %% [markdown]
# # Peticions

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/svm" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Biscoe\",\
    \"bill_length_mm\": 49.0,\
    \"bill_depth_mm\": 15.8,\
    \"flipper_length_mm\": 220.0,\
    \"body_mass_g\": 5500.0,\
    \"sex\": \"Male\"\
}"
# Out:
# {"prediccio_especie":"Gentoo"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/svm" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Torgersen\",\
    \"bill_length_mm\": 37.0,\
    \"bill_depth_mm\": 18.0,\
    \"flipper_length_mm\": 190.0,\
    \"body_mass_g\": 3500.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Adelie"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/svm" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Dream\",\
    \"bill_length_mm\": 48.0,\
    \"bill_depth_mm\": 16.5,\
    \"flipper_length_mm\": 195.0,\
    \"body_mass_g\": 3800.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Chinstrap"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/log_reg" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Biscoe\",\
    \"bill_length_mm\": 49.0,\
    \"bill_depth_mm\": 15.8,\
    \"flipper_length_mm\": 220.0,\
    \"body_mass_g\": 5500.0,\
    \"sex\": \"Male\"\
}"
# Out:
# {"prediccio_especie":"Gentoo"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/log_reg" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Torgersen\",\
    \"bill_length_mm\": 37.0,\
    \"bill_depth_mm\": 18.0,\
    \"flipper_length_mm\": 190.0,\
    \"body_mass_g\": 3500.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Adelie"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/log_reg" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Dream\",\
    \"bill_length_mm\": 48.0,\
    \"bill_depth_mm\": 16.5,\
    \"flipper_length_mm\": 195.0,\
    \"body_mass_g\": 3800.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Chinstrap"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/dt" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Biscoe\",\
    \"bill_length_mm\": 49.0,\
    \"bill_depth_mm\": 15.8,\
    \"flipper_length_mm\": 220.0,\
    \"body_mass_g\": 5500.0,\
    \"sex\": \"Male\"\
}"
# Out:
# {"prediccio_especie":"Gentoo"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/dt" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Torgersen\",\
    \"bill_length_mm\": 37.0,\
    \"bill_depth_mm\": 18.0,\
    \"flipper_length_mm\": 190.0,\
    \"body_mass_g\": 3500.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Adelie"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/dt" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Dream\",\
    \"bill_length_mm\": 48.0,\
    \"bill_depth_mm\": 16.5,\
    \"flipper_length_mm\": 195.0,\
    \"body_mass_g\": 3800.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Chinstrap"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/knn" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Biscoe\",\
    \"bill_length_mm\": 49.0,\
    \"bill_depth_mm\": 15.8,\
    \"flipper_length_mm\": 220.0,\
    \"body_mass_g\": 5500.0,\
    \"sex\": \"Male\"\
}"
# Out:
# {"prediccio_especie":"Gentoo"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/knn" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Torgersen\",\
    \"bill_length_mm\": 37.0,\
    \"bill_depth_mm\": 18.0,\
    \"flipper_length_mm\": 190.0,\
    \"body_mass_g\": 3500.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Adelie"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/knn" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Dream\",\
    \"bill_length_mm\": 48.0,\
    \"bill_depth_mm\": 16.5,\
    \"flipper_length_mm\": 195.0,\
    \"body_mass_g\": 3800.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Chinstrap"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/knn" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Dream\",\
    \"bill_length_mm\": 50.0,\
    \"bill_depth_mm\": 16.5,\
    \"flipper_length_mm\": 175.0,\
    \"body_mass_g\": 5000.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Chinstrap"}

# %%
# !curl --request POST "http://127.0.0.1:5000/predict/dt" \
--header "Content-Type: application/json" \
--data-raw "{\
    \"island\": \"Dream\",\
    \"bill_length_mm\": 50.0,\
    \"bill_depth_mm\": 16.5,\
    \"flipper_length_mm\": 175.0,\
    \"body_mass_g\": 5000.0,\
    \"sex\": \"Female\"\
}"
# Out:
# {"prediccio_especie":"Chinstrap"}
